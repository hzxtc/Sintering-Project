# %%
import numpy as np
import matplotlib.pyplot as plt
import statistics as st
import os
import csv

steplines = []
with open("metropolis","rt") as file:
    for line in file:
        if line.startswith("s"):
            steplines.append(line.rstrip('\n'))

numberOfCluster = []
steps = []
for i in range(len(steplines)):
    steps.append(i + 1)
    
for j in range(len(steplines)):
    numberOfCluster.append(float(steplines[j].split()[5]))

plt.figure(figsize=(15,8))
plt.plot(steps,numberOfCluster,label="clusters GM n =2")
plt.title("100 GM clusters size 750 K all n =2")
plt.xlabel("step number")
plt.ylabel("number of clusters")
plt.legend()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import statistics as st
import os
import csv

steplines = []
with open("metropolis","rt") as file:
    for line in file:
        if line.startswith("s"):
            steplines.append(line.rstrip('\n'))

numberOfCluster = []
steps = []
for i in range(len(steplines)):
    steps.append(i + 1)
    
for j in range(len(steplines)):
    numberOfCluster.append(float(steplines[j].split()[5]))

plt.figure(figsize=(15,8))
plt.plot(steps,numberOfCluster,label="clusters GM n =3")
plt.title("100 GM clusters size 750 K all n =3")
plt.xlabel("step number")
plt.ylabel("number of clusters")
plt.legend()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import statistics as st
import os
import csv

steplines = []
with open("metropolis","rt") as file:
    for line in file:
        if line.startswith("s"):
            steplines.append(line.rstrip('\n'))

numberOfCluster = []
steps = []
for i in range(len(steplines)):
    steps.append(i + 1)
    
for j in range(len(steplines)):
    numberOfCluster.append(float(steplines[j].split()[5]))

plt.figure(figsize=(15,8))
plt.plot(steps,numberOfCluster,label="clusters GM n =4")
plt.title("100 GM clusters size 750 K all n =4")
plt.xlabel("step number")
plt.ylabel("number of clusters")
plt.legend()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import statistics as st
import os
import csv

steplines = []
with open("metropolis","rt") as file:
    for line in file:
        if line.startswith("s"):
            steplines.append(line.rstrip('\n'))

numberOfCluster = []
steps = []
for i in range(len(steplines)):
    steps.append(i + 1)
    
for j in range(len(steplines)):
    numberOfCluster.append(float(steplines[j].split()[5]))

plt.figure(figsize=(15,8))
plt.plot(steps,numberOfCluster,label="clusters GM n =5")
plt.title("100 GM clusters size 750 K all n =5")
plt.xlabel("step number")
plt.ylabel("number of clusters")
plt.legend()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import statistics as st
import os
import csv

steplines = []
with open("metropolis","rt") as file:
    for line in file:
        if line.startswith("s"):
            steplines.append(line.rstrip('\n'))

numberOfCluster = []
steps = []
for i in range(len(steplines)):
    steps.append(i + 1)
    
for j in range(len(steplines)):
    numberOfCluster.append(float(steplines[j].split()[5]))

plt.figure(figsize=(15,8))
plt.plot(steps,numberOfCluster,label="clusters GM n =6")
plt.title("100 GM clusters size 750 K all n =6")
plt.xlabel("step number")
plt.ylabel("number of clusters")
plt.legend()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import statistics as st
import os
import csv

steplines = []
with open("metropolis","rt") as file:
    for line in file:
        if line.startswith("s"):
            steplines.append(line.rstrip('\n'))

numberOfCluster = []
steps = []
for i in range(len(steplines)):
    steps.append(i + 1)
    
for j in range(len(steplines)):
    numberOfCluster.append(float(steplines[j].split()[5]))

plt.figure(figsize=(15,8))
plt.plot(steps,numberOfCluster,label="clusters GM n =7")
plt.title("100 GM clusters size 750 K all n =7")
plt.xlabel("step number")
plt.ylabel("number of clusters")
plt.legend()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import statistics as st
import os
import csv

steplines = []
with open("metropolis","rt") as file:
    for line in file:
        if line.startswith("s"):
            steplines.append(line.rstrip('\n'))

numberOfCluster = []
steps = []
for i in range(len(steplines)):
    steps.append(i + 1)
    
for j in range(len(steplines)):
    numberOfCluster.append(float(steplines[j].split()[5]))

plt.figure(figsize=(15,8))
plt.plot(steps,numberOfCluster,label="clusters GM n =1")
plt.title("100 GM clusters size 750 K all n =1")
plt.xlabel("step number")
plt.ylabel("number of clusters")
plt.legend()
plt.show()
