# %%
import numpy as np
import matplotlib.pyplot as plt
import statistics as st
import os
import csv

steplines = []
with open("metropolis","rt") as file:
    for line in file:
        if line.startswith("s"):
            steplines.append(line.rstrip('\n'))

numberOfCluster = []
steps = []
for i in range(len(steplines)):
    steps.append(i + 1)
    
for j in range(len(steplines)):
    numberOfCluster.append(float(steplines[j].split()[5]))

plt.figure(figsize=(15,8))
plt.plot(steps,numberOfCluster,label="clusters random n =2")
plt.title("100 Boltzmann clusters size 700 K all no overlap limit n = 2")
plt.xlabel("step number")
plt.ylabel("number of clusters")
plt.legend()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import statistics as st
import os
import csv

steplines = []
with open("metropolis","rt") as file:
    for line in file:
        if line.startswith("s"):
            steplines.append(line.rstrip('\n'))

numberOfCluster = []
steps = []
for i in range(len(steplines)):
    steps.append(i + 1)
    
for j in range(len(steplines)):
    numberOfCluster.append(float(steplines[j].split()[5]))

plt.figure(figsize=(15,8))
plt.plot(steps,numberOfCluster,label="clusters random n =3")
plt.title("100 Boltzmann clusters size 700 K all no overlap limit n = 3")
plt.xlabel("step number")
plt.ylabel("number of clusters")
plt.legend()
plt.show()

# %% [markdown]
# $n = 3$ is a straignt line paralel to the x axis if there is no other type of clusters other than the GM one. Once there is another type of cluster, then that cluster will grow into bigger cluster. But strangely, the final number of cluster will always be $100 - 4 = 94$ for many runs.

# %%
import numpy as np
import matplotlib.pyplot as plt
import statistics as st
import os
import csv

steplines = []
with open("metropolis","rt") as file:
    for line in file:
        if line.startswith("s"):
            steplines.append(line.rstrip('\n'))

numberOfCluster = []
steps = []
for i in range(len(steplines)):
    steps.append(i + 1)
    
for j in range(len(steplines)):
    numberOfCluster.append(float(steplines[j].split()[5]))

plt.figure(figsize=(15,8))
plt.plot(steps,numberOfCluster,label="clusters random n =4")
plt.title("100 Boltzmann clusters size 700 K all no overlap limit n = 4")
plt.xlabel("step number")
plt.ylabel("number of clusters")
plt.legend()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import statistics as st
import os
import csv

steplines = []
with open("metropolis","rt") as file:
    for line in file:
        if line.startswith("s"):
            steplines.append(line.rstrip('\n'))

numberOfCluster = []
steps = []
for i in range(len(steplines)):
    steps.append(i + 1)
    
for j in range(len(steplines)):
    numberOfCluster.append(float(steplines[j].split()[5]))

plt.figure(figsize=(15,8))
plt.plot(steps,numberOfCluster,label="clusters random n = 5")
plt.title("100 Boltzmann clusters size 700 K all no overlap limit n = 5")
plt.xlabel("step number")
plt.ylabel("number of clusters")
plt.legend()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import statistics as st
import os
import csv

steplines = []
with open("metropolis","rt") as file:
    for line in file:
        if line.startswith("s"):
            steplines.append(line.rstrip('\n'))

numberOfCluster = []
steps = []
for i in range(len(steplines)):
    steps.append(i + 1)
    
for j in range(len(steplines)):
    numberOfCluster.append(float(steplines[j].split()[5]))

plt.figure(figsize=(15,8))
plt.plot(steps,numberOfCluster,label="clusters random n = 6")
plt.title("100 Boltzmann clusters size 700 K all no overlap limit n = 6")
plt.xlabel("step number")
plt.ylabel("number of clusters")
plt.legend()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import statistics as st
import os
import csv

steplines = []
with open("metropolis","rt") as file:
    for line in file:
        if line.startswith("s"):
            steplines.append(line.rstrip('\n'))

numberOfCluster = []
steps = []
for i in range(len(steplines)):
    steps.append(i + 1)
    
for j in range(len(steplines)):
    numberOfCluster.append(float(steplines[j].split()[5]))

plt.figure(figsize=(15,8))
plt.plot(steps,numberOfCluster,label="clusters random n = 7")
plt.title("100 Boltzmann clusters size 700 K all no overlap limit n = 7")
plt.xlabel("step number")
plt.ylabel("number of clusters")
plt.legend()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import statistics as st
import os
import csv

steplines = []
with open("metropolis","rt") as file:
    for line in file:
        if line.startswith("s"):
            steplines.append(line.rstrip('\n'))

numberOfCluster = []
steps = []
for i in range(len(steplines)):
    steps.append(i + 1)
    
for j in range(len(steplines)):
    numberOfCluster.append(float(steplines[j].split()[5]))

plt.figure(figsize=(15,8))
plt.plot(steps,numberOfCluster,label="clusters random n = 8")
plt.title("100 Boltzmann clusters size 700 K all no overlap limit n = 8")
plt.xlabel("step number")
plt.ylabel("number of clusters")
plt.legend()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import statistics as st
import os
import csv

steplines = []
with open("metropolis","rt") as file:
    for line in file:
        if line.startswith("s"):
            steplines.append(line.rstrip('\n'))

numberOfCluster = []
steps = []
for i in range(len(steplines)):
    steps.append(i + 1)
    
for j in range(len(steplines)):
    numberOfCluster.append(float(steplines[j].split()[5]))

plt.figure(figsize=(15,8))
plt.plot(steps,numberOfCluster,label="clusters random n = 2")
plt.title("situation1 100 clusters size 700 K all no overlap limit n = 2")
plt.xlabel("step number")
plt.ylabel("number of clusters")
plt.legend()
plt.show()

# %% [markdown]
# There are two situations for n = 2 here: one is this one here stable decrease to 75 +or- 10
# Another one is quite strange, which is the below situation that fasten the sintering process eventhough I set the overlap limit to 1. but this is only for 1000 step

# %%
import numpy as np
import matplotlib.pyplot as plt
import statistics as st
import os
import csv

steplines = []
with open("metropolis","rt") as file:
    for line in file:
        if line.startswith("s"):
            steplines.append(line.rstrip('\n'))

numberOfCluster = []
steps = []
for i in range(len(steplines)):
    steps.append(i + 1)
    
for j in range(len(steplines)):
    numberOfCluster.append(float(steplines[j].split()[5]))

plt.figure(figsize=(15,8))
plt.plot(steps,numberOfCluster,label="clusters random n = 2")
plt.title("situation2 100 clusters size 700 K all no overlap limit n = 2")
plt.xlabel("step number")
plt.ylabel("number of clusters")
plt.legend()
plt.show()

# %% [markdown]
# when i switch the order for checking normal overlap first and then boundary overlap, it looks like this:

# %%
import numpy as np
import matplotlib.pyplot as plt
import statistics as st
import os
import csv

steplines = []
with open("metropolis","rt") as file:
    for line in file:
        if line.startswith("s"):
            steplines.append(line.rstrip('\n'))

numberOfCluster = []
steps = []
for i in range(len(steplines)):
    steps.append(i + 1)
    
for j in range(len(steplines)):
    numberOfCluster.append(float(steplines[j].split()[5]))

plt.figure(figsize=(15,8))
plt.plot(steps,numberOfCluster,label="clusters random n = 2")
plt.title("later overlap boundary check 100 clusters size 700 K all no overlap limit n = 2")
plt.xlabel("step number")
plt.ylabel("number of clusters")
plt.legend()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import statistics as st
import os
import csv

steplines = []
with open("metropolis","rt") as file:
    for line in file:
        if line.startswith("s"):
            steplines.append(line.rstrip('\n'))

numberOfCluster = []
steps = []
for i in range(len(steplines)):
    steps.append(i + 1)
    
for j in range(len(steplines)):
    numberOfCluster.append(float(steplines[j].split()[5]))

plt.figure(figsize=(15,8))
plt.plot(steps,numberOfCluster,label="clusters random n = 3")
plt.title("later overlap boundary check 100 clusters size 700 K all no overlap limit n = 3")
plt.xlabel("step number")
plt.ylabel("number of clusters")
plt.legend()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import statistics as st
import os
import csv

steplines = []
with open("metropolis","rt") as file:
    for line in file:
        if line.startswith("s"):
            steplines.append(line.rstrip('\n'))

numberOfCluster = []
steps = []
for i in range(len(steplines)):
    steps.append(i + 1)
    
for j in range(len(steplines)):
    numberOfCluster.append(float(steplines[j].split()[5]))

plt.figure(figsize=(15,8))
plt.plot(steps,numberOfCluster,label="clusters n =2")
plt.title("100 Boltzmann clusters plus 10 single atoms size 700 K all no overlap limit n = 2")
plt.xlabel("step number")
plt.ylabel("number of clusters")
plt.legend()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import statistics as st
import os
import csv

steplines = []
with open("metropolis","rt") as file:
    for line in file:
        if line.startswith("s"):
            steplines.append(line.rstrip('\n'))

numberOfCluster = []
steps = []
for i in range(len(steplines)):
    steps.append(i + 1)
    
for j in range(len(steplines)):
    numberOfCluster.append(float(steplines[j].split()[5]))

plt.figure(figsize=(15,8))
plt.plot(steps,numberOfCluster,label="clusters n =2")
plt.title("100 Boltzmann clusters plus 20 single atoms size 700 K all no overlap limit n = 2")
plt.xlabel("step number")
plt.ylabel("number of clusters")
plt.legend()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import statistics as st
import os
import csv

steplines = []
with open("metropolis","rt") as file:
    for line in file:
        if line.startswith("s"):
            steplines.append(line.rstrip('\n'))

numberOfCluster = []
steps = []
for i in range(len(steplines)):
    steps.append(i + 1)
    
for j in range(len(steplines)):
    numberOfCluster.append(float(steplines[j].split()[5]))

plt.figure(figsize=(15,8))
plt.plot(steps,numberOfCluster,label="clusters n = 2")
plt.title("100 Boltzmann clusters plus 30 single atoms size 700 K all no overlap limit n = 2")
plt.xlabel("step number")
plt.ylabel("number of clusters")
plt.legend()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import statistics as st
import os
import csv

steplines = []
with open("metropolis","rt") as file:
    for line in file:
        if line.startswith("s"):
            steplines.append(line.rstrip('\n'))

numberOfCluster = []
steps = []
for i in range(len(steplines)):
    steps.append(i + 1)
    
for j in range(len(steplines)):
    numberOfCluster.append(float(steplines[j].split()[5]))

plt.figure(figsize=(15,8))
plt.plot(steps,numberOfCluster,label="clusters n = 2")
plt.title("100 Boltzmann clusters plus 50 single atoms size 700 K all no overlap limit n = 2")
plt.xlabel("step number")
plt.ylabel("number of clusters")
plt.legend()
plt.show()
