# %%
import numpy as np

for index in range(9,1001):
    with open('DATA', 'a') as f2:
        newEnergy = (-5.187 * index - 1963) / 27.2114 - (-73.66723149)
        newRadius = 1.290 * np.log(index) + 1.750 # need to be fixed!!!
        f2.write('%3i %16.8f %16.8f %16.8f %16.8f \n' %
                    ( index ,  newRadius, 0, 0, newEnergy))

# %%
with open('DATA', 'r') as f1:
    firstline = f1.readline()
    data = f1.readlines()
    n = 0
    for line in data:
        print(str(n) + ": " + str( int(line.split()[0])))
        n = n + 1
# Out:
# 0: 2
# 1: 2
# 2: 2
# 3: 2
# 4: 2
# 5: 2
# 6: 2
# 7: 2
# 8: 3
# 9: 3
# 10: 3
# 11: 3
# 12: 3
# 13: 3
# 14: 3
# 15: 3
# 16: 3
# 17: 3
# 18: 3
# 19: 3
# 20: 4
# 21: 4
# 22: 4
# 23: 4
# 24: 4
# 25: 4
# 26: 5
# 27: 5
# 28: 5
# 29: 5
# 30: 5
# 31: 5
# 32: 5
# 33: 5
# 34: 5
# 35: 5
# 36: 5
# 37: 5
# 38: 5
# 39: 5
# 40: 5
# 41: 5
# 42: 5
# 43: 5
# 44: 5
# 45: 6
# 46: 6
# 47: 6
# 48: 6
# 49: 7
# 50: 7
# 51: 7
# 52: 7
# 53: 7
# 54: 7
# 55: 7
# 56: 7
# 57: 7
# 58: 7
# 59: 7
# 60: 8
# 61: 8
# 62: 8
# 63: 9
# 64: 10
# 65: 11
# 66: 12
# 67: 13
# 68: 14
# 69: 15
# 70: 16
# 71: 17
# 72: 18
# 73: 19
# 74: 20
# 75: 21
# 76: 22
# 77: 23
# 78: 24
# 79: 25
# 80: 26
# 81: 27
# 82: 28
# 83: 29
# 84: 30
# 85: 31
# 86: 32
# 87: 33
# 88: 34
# 89: 35
# 90: 36
# 91: 37
# 92: 38
# 93: 39
# 94: 40
# 95: 41
# 96: 42
# 97: 43
# 98: 44
# 99: 45
# 100: 46
# 101: 47
# 102: 48
# 103: 49
# 104: 50
# 105: 51
# 106: 52
# 107: 53
# 108: 54
# 109: 55
# 110: 56
# 111: 57
# 112: 58
# 113: 59
# 114: 60
# 115: 61
# 116: 62
# ...
